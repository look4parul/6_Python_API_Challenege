# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import pprint
from datetime import date
from decimal import Decimal


# Import API key
import api_keys

# Import citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output_Data/weather_data.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for coordinates in lat_lngs:
    city = citipy.nearest_city(coordinates[0], coordinates[1]).city_name
# Replace spaces with "_" to create url correctly 
    city = city.replace(" ", "_")    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Openweather map API key
api_key = api_keys.api_key

# %%
#Create a function to get json value
def get_weather_json(city, api_key):
    url = "http://api.openweathermap.org/data/2.5/forecast"
    r = requests.get(url, params={
        "appid": api_key,
        "q": city,
        "units": "imperial"
    })
    if r.status_code ==200:
        r_json = r.json()
        return r_json
    else:
        return None

# %%
# Print the output json values
#pprint.pprint(get_weather_json(city,api_key),indent =4)

# %%
# Declare the list of elements for data frame
out_cities = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []

# %%
# Set the initial values for set and record variables
record = 0
set = 1

# Print the output as per the required output
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

for in_city in cities:
    response = get_weather_json(in_city.replace(" ", "_"), api_key)
    
    if response:
        # Append the values for all DataFrame variables 
        cloudiness.append(response['list'][0]['clouds']['all'])
        city_data = response['city']
        country.append(city_data['country'])
        date.append(response['list'][0]["dt"])
        humidity.append(response['list'][0]['main']['humidity'])
        latitude.append(Decimal(city_data['coord']['lat']).quantize(Decimal(10) ** -2  ))
        longitude.append(Decimal(city_data['coord']['lon']).quantize(Decimal(10) ** -2  ))
        max_temp.append(Decimal(response['list'][0]['main']['temp_max']).quantize(Decimal(10) ** -2  ))
        wind_speed.append(response['list'][0]['wind']['speed'])
        # Check to increment the value of set as per the required output and append the cities for DataFrame
        if record > 49:
            record = 1
            set += 1
            out_cities.append(in_city)
        else:
            record += 1
            out_cities.append(in_city)
        print(f"Processing Record {record} of Set {set} | {in_city}")
        #time.sleep(0.001)
    # Check if the city is not in the list
    else:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | erzin
# Processing Record 2 of Set 1 | hambantota
# Processing Record 3 of Set 1 | tuktoyaktuk
# Processing Record 4 of Set 1 | husavik
# Processing Record 5 of Set 1 | bima
# City not found. Skipping...
# Processing Record 6 of Set 1 | cherskiy
# Processing Record 7 of Set 1 | nikolskoye
# Processing Record 8 of Set 1 | havoysund
# Processing Record 9 of Set 1 | butaritari
# Processing Record 10 of Set 1 | yellowknife
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | chokurdakh
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | leningradskiy
# City not found. Skipping...
# Processing Record 16 of Set 1 | hobart
# Processing Record 17 of Set 1 | usinsk
# Processing Record 18 of Set 1 | ushuaia
# Processing Record 19 of Set 1 | troitsko-pechorsk
# City not found. Skipping...
# Processing Record 20 of Set 1 | longyearbyen
# Processing Record 21 of Set 1 | rikitea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 22 of Set 1 | qaanaaq
# Processing Record 23 of Set 1 | chumphon
# City not found. Skipping...
# Processing Record 24 of Set 1 | payo
# City not found. Skipping...
# Processing Record 25 of Set 1 | hilo
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 1 | hovd
# Processing Record 27 of Set 1 | vardo
# Processing Record 28 of Set 1 | bluff
# City not found. Skipping...
# Processing Record 29 of Set 1 | nichinan
# Processing Record 30 of Set 1 | mehamn
# City not found. Skipping...
# Processing Record 31 of Set 1 | kisangani
# Processing Record 32 of Set 1 | tessalit
# Processing Record 33 of Set 1 | mahebourg
# City not found. Skipping...
# Processing Record 34 of Set 1 | inta
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | nouakchott
# Processing Record 37 of Set 1 | mataura
# Processing Record 38 of Set 1 | kodiak
# Processing Record 39 of Set 1 | caravelas
# Processing Record 40 of Set 1 | kasane
# Processing Record 41 of Set 1 | victoria
# Processing Record 42 of Set 1 | chuy
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | camabatela
# City not found. Skipping...
# Processing Record 45 of Set 1 | sisimiut
# Processing Record 46 of Set 1 | oranjemund
# City not found. Skipping...
# Processing Record 47 of Set 1 | westport
# Processing Record 48 of Set 1 | suntar
# Processing Record 49 of Set 1 | nanortalik
# City not found. Skipping...
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | dubbo
# Processing Record 2 of Set 2 | hermanus
# City not found. Skipping...
# Processing Record 3 of Set 2 | carnarvon
# City not found. Skipping...
# Processing Record 4 of Set 2 | divnomorskoye
# Processing Record 5 of Set 2 | faya
# Processing Record 6 of Set 2 | goderich
# Processing Record 7 of Set 2 | busselton
# Processing Record 8 of Set 2 | itarema
# Processing Record 9 of Set 2 | kavieng
# City not found. Skipping...
# Processing Record 10 of Set 2 | dikson
# City not found. Skipping...
# Processing Record 11 of Set 2 | labuan
# Processing Record 12 of Set 2 | hasaki
# Processing Record 13 of Set 2 | maracacume
# Processing Record 14 of Set 2 | corinto
# City not found. Skipping...
# Processing Record 15 of Set 2 | barrow
# Processing Record 16 of Set 2 | inhambane
# Processing Record 17 of Set 2 | saint-pierre
# Processing Record 18 of Set 2 | marzuq
# Processing Record 19 of Set 2 | narsaq
# Processing Record 20 of Set 2 | rudozem
# Processing Record 21 of Set 2 | sibanicu
# Processing Record 22 of Set 2 | saskylakh
# City not found. Skipping...
# Processing Record 23 of Set 2 | college
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 2 | atuona
# Processing Record 25 of Set 2 | pevek
# Processing Record 26 of Set 2 | kholm
# Processing Record 27 of Set 2 | faridpur
# Processing Record 28 of Set 2 | noyabrsk
# City not found. Skipping...
# Processing Record 29 of Set 2 | saint-louis
# Processing Record 30 of Set 2 | iracoubo
# City not found. Skipping...
# Processing Record 31 of Set 2 | hithadhoo
# Processing Record 32 of Set 2 | khatanga
# Processing Record 33 of Set 2 | mikhaylovka
# City not found. Skipping...
# Processing Record 34 of Set 2 | soure
# Processing Record 35 of Set 2 | geraldton
# Processing Record 36 of Set 2 | chara
# Processing Record 37 of Set 2 | ahipara
# Processing Record 38 of Set 2 | nemuro
# Processing Record 39 of Set 2 | kruisfontein
# City not found. Skipping...
# Processing Record 40 of Set 2 | saint-philippe
# City not found. Skipping...
# Processing Record 41 of Set 2 | pemba
# Processing Record 42 of Set 2 | meulaboh
# Processing Record 43 of Set 2 | goundam
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of Set 2 | saldanha
# Processing Record 45 of Set 2 | turek
# Processing Record 46 of Set 2 | balakhninskiy
# Processing Record 47 of Set 2 | aracruz
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 2 | bethel
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 2 | kapaa
# Processing Record 50 of Set 2 | mirnyy
# Processing Record 1 of Set 3 | barcelona
# Processing Record 2 of Set 3 | fairbanks
# City not found. Skipping...
# Processing Record 3 of Set 3 | adrar
# Processing Record 4 of Set 3 | codrington
# Processing Record 5 of Set 3 | taltal
# City not found. Skipping...
# Processing Record 6 of Set 3 | kollam
# Processing Record 7 of Set 3 | ust-nera
# Processing Record 8 of Set 3 | ovalle
# Processing Record 9 of Set 3 | esperance
# Processing Record 10 of Set 3 | beloha
# Processing Record 11 of Set 3 | bilibino
# City not found. Skipping...
# Processing Record 12 of Set 3 | komsomolskiy
# Processing Record 13 of Set 3 | cayenne
# Processing Record 14 of Set 3 | asosa
# Processing Record 15 of Set 3 | margate
# City not found. Skipping...
# Processing Record 16 of Set 3 | tuatapere
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 3 | hami
# Processing Record 18 of Set 3 | canalete
# Processing Record 19 of Set 3 | antofagasta
# Processing Record 20 of Set 3 | xai-xai
# Processing Record 21 of Set 3 | tautira
# Processing Record 22 of Set 3 | lamu
# Processing Record 23 of Set 3 | georgetown
# Processing Record 24 of Set 3 | nantucket
# Processing Record 25 of Set 3 | lavrentiya
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | faanui
# City not found. Skipping...
# Processing Record 28 of Set 3 | klaksvik
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 29 of Set 3 | akcaabat
# Processing Record 30 of Set 3 | pinyug
# City not found. Skipping...
# Processing Record 31 of Set 3 | sheltozero
# Processing Record 32 of Set 3 | isangel
# Processing Record 33 of Set 3 | sept-iles
# Processing Record 34 of Set 3 | lata
# Processing Record 35 of Set 3 | ampanihy
# Processing Record 36 of Set 3 | machico
# Processing Record 37 of Set 3 | borogontsy
# Processing Record 38 of Set 3 | kudahuvadhoo
# Processing Record 39 of Set 3 | egvekinot
# Processing Record 40 of Set 3 | hofn
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 3 | tiksi
# City not found. Skipping...
# Processing Record 42 of Set 3 | tazovskiy
# Processing Record 43 of Set 3 | parana
# Processing Record 44 of Set 3 | ormara
# Processing Record 45 of Set 3 | halifax
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 3 | manaure
# City not found. Skipping...
# Processing Record 47 of Set 3 | yumbe
# City not found. Skipping...
# Processing Record 48 of Set 3 | salalah
# City not found. Skipping...
# Processing Record 49 of Set 3 | cabedelo
# Processing Record 50 of Set 3 | calabar
# City not found. Skipping...
# Processing Record 1 of Set 4 | provideniya
# Processing Record 2 of Set 4 | tarsus
# City not found. Skipping...
# Processing Record 3 of Set 4 | ekhabi
# Processing Record 4 of Set 4 | lorca
# Processing Record 5 of Set 4 | vanimo
# City not found. Skipping...
# Processing Record 6 of Set 4 | aykhal
# Processing Record 7 of Set 4 | vaini
# City not found. Skipping...
# Processing Record 8 of Set 4 | zyryanka
# Processing Record 9 of Set 4 | namibe
# Processing Record 10 of Set 4 | esmeraldas
# Processing Record 11 of Set 4 | skibbereen
# City not found. Skipping...
# Processing Record 12 of Set 4 | maputo
# Processing Record 13 of Set 4 | mizdah
# City not found. Skipping...
# Processing Record 14 of Set 4 | airai
# Processing Record 15 of Set 4 | llanes
# Processing Record 16 of Set 4 | marawi
# City not found. Skipping...
# Processing Record 17 of Set 4 | ostrovnoy
# City not found. Skipping...
# Processing Record 18 of Set 4 | camacari
# City not found. Skipping...
# Processing Record 19 of Set 4 | homer
# Processing Record 20 of Set 4 | kaitangata
# Processing Record 21 of Set 4 | leh
# Processing Record 22 of Set 4 | ahuimanu
# Processing Record 23 of Set 4 | vao
# Processing Record 24 of Set 4 | leshukonskoye
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 4 | ploemeur
# City not found. Skipping...
# Processing Record 26 of Set 4 | teknaf
# Processing Record 27 of Set 4 | broome
# Processing Record 28 of Set 4 | gambela
# Processing Record 29 of Set 4 | mabaruma
# Processing Record 30 of Set 4 | skierniewice
# Processing Record 31 of Set 4 | christchurch
# Processing Record 32 of Set 4 | rockport
# City not found. Skipping...
# Processing Record 33 of Set 4 | micheweni
# City not found. Skipping...
# Processing Record 34 of Set 4 | panalingaan
# Processing Record 35 of Set 4 | pelagiada
# Processing Record 36 of Set 4 | ust-tsilma
# Processing Record 37 of Set 4 | kautokeino
# Processing Record 38 of Set 4 | kalevala
# City not found. Skipping...
# Processing Record 39 of Set 4 | lilongwe
# Processing Record 40 of Set 4 | ancud
# Processing Record 41 of Set 4 | kiama
# Processing Record 42 of Set 4 | zabol
# City not found. Skipping...
# Processing Record 43 of Set 4 | akhtanizovskaya
# Processing Record 44 of Set 4 | bongandanga
# Processing Record 45 of Set 4 | noumea
# Processing Record 46 of Set 4 | penzance
# Processing Record 47 of Set 4 | floro
# Processing Record 48 of Set 4 | muli
# Processing Record 49 of Set 4 | mwingi
# Processing Record 50 of Set 4 | whitehorse
# Processing Record 1 of Set 5 | pachino
# Processing Record 2 of Set 5 | shizuishan
# Processing Record 3 of Set 5 | saryg-sep
# Processing Record 4 of Set 5 | zaysan
# Processing Record 5 of Set 5 | fukue
# City not found. Skipping...
# Processing Record 6 of Set 5 | atyrau
# City not found. Skipping...
# Processing Record 7 of Set 5 | tanabe
# Processing Record 8 of Set 5 | ibra
# Processing Record 9 of Set 5 | itaituba
# Processing Record 10 of Set 5 | luderitz
# Processing Record 11 of Set 5 | krusevac
# Processing Record 12 of Set 5 | waharoa
# Processing Record 13 of Set 5 | gat
# City not found. Skipping...
# Processing Record 14 of Set 5 | kichera
# Processing Record 15 of Set 5 | grindavik
# Processing Record 16 of Set 5 | mataram
# Processing Record 17 of Set 5 | bollnas
# Processing Record 18 of Set 5 | praya
# Processing Record 19 of Set 5 | saint-georges
# Processing Record 20 of Set 5 | nizwa
# Processing Record 21 of Set 5 | coquimbo
# Processing Record 22 of Set 5 | sistranda
# City not found. Skipping...
# Processing Record 23 of Set 5 | sylling
# City not found. Skipping...
# Processing Record 24 of Set 5 | tamiahua
# Processing Record 25 of Set 5 | baruun-urt
# City not found. Skipping...
# Processing Record 26 of Set 5 | nouadhibou
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | kandrian
# Processing Record 29 of Set 5 | altamira
# Processing Record 30 of Set 5 | linxia
# Processing Record 31 of Set 5 | castro
# City not found. Skipping...
# Processing Record 32 of Set 5 | podor
# Processing Record 33 of Set 5 | naze
# Processing Record 34 of Set 5 | dunedin
# Processing Record 35 of Set 5 | anastacio
# Processing Record 36 of Set 5 | navsari
# Processing Record 37 of Set 5 | sudzha
# Processing Record 38 of Set 5 | sorgun
# Processing Record 39 of Set 5 | naryan-mar
# Processing Record 40 of Set 5 | palora
# Processing Record 41 of Set 5 | kamwenge
# Processing Record 42 of Set 5 | merauke
# Processing Record 43 of Set 5 | lagunas
# Processing Record 44 of Set 5 | imbituba
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 5 | fortuna
# Processing Record 46 of Set 5 | katherine
# City not found. Skipping...
# Processing Record 47 of Set 5 | pangnirtung
# Processing Record 48 of Set 5 | touros
# Processing Record 49 of Set 5 | guanare
# Processing Record 50 of Set 5 | nakkila
# Processing Record 1 of Set 6 | ler
# Processing Record 2 of Set 6 | mbarara
# Processing Record 3 of Set 6 | sabaudia
# Processing Record 4 of Set 6 | ganzhou
# Processing Record 5 of Set 6 | portree
# Processing Record 6 of Set 6 | namatanai
# City not found. Skipping...
# Processing Record 7 of Set 6 | bose
# City not found. Skipping...
# Processing Record 8 of Set 6 | along
# Processing Record 9 of Set 6 | sitka
# City not found. Skipping...
# Processing Record 10 of Set 6 | jadu
# Processing Record 11 of Set 6 | riverton
# Processing Record 12 of Set 6 | constitucion
# City not found. Skipping...
# Processing Record 13 of Set 6 | lovington
# Processing Record 14 of Set 6 | necochea
# Processing Record 15 of Set 6 | yurginskoye
# Processing Record 16 of Set 6 | tasiilaq
# Processing Record 17 of Set 6 | lorengau
# Processing Record 18 of Set 6 | rocha
# Processing Record 19 of Set 6 | mitsamiouli
# Processing Record 20 of Set 6 | iqaluit
# Processing Record 21 of Set 6 | menongue
# City not found. Skipping...
# Processing Record 22 of Set 6 | souillac
# Processing Record 23 of Set 6 | lannion
# Processing Record 24 of Set 6 | dagana
# City not found. Skipping...
# Processing Record 25 of Set 6 | chapais
# Processing Record 26 of Set 6 | clarksburg
# City not found. Skipping...
# Processing Record 27 of Set 6 | lobito
# Processing Record 28 of Set 6 | nago
# Processing Record 29 of Set 6 | nyurba
# City not found. Skipping...
# Processing Record 30 of Set 6 | kalianget
# Processing Record 31 of Set 6 | katsuura
# City not found. Skipping...
# Processing Record 32 of Set 6 | ozinki
# Processing Record 33 of Set 6 | yulara
# City not found. Skipping...
# Processing Record 34 of Set 6 | urucara
# Processing Record 35 of Set 6 | nioro
# Processing Record 36 of Set 6 | caraballeda
# Processing Record 37 of Set 6 | asuncion
# City not found. Skipping...
# Processing Record 38 of Set 6 | payson
# Processing Record 39 of Set 6 | boysun
# Processing Record 40 of Set 6 | eureka
# Processing Record 41 of Set 6 | igarka
# Processing Record 42 of Set 6 | quthing
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 6 | rosarito
# Processing Record 44 of Set 6 | rawson
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 6 | cedartown
# Processing Record 46 of Set 6 | arman
# Processing Record 47 of Set 6 | liancheng
# City not found. Skipping...
# Processing Record 48 of Set 6 | santona
# Processing Record 49 of Set 6 | mamallapuram
# Processing Record 50 of Set 6 | daru
# City not found. Skipping...
# Processing Record 1 of Set 7 | lumeje
# Processing Record 2 of Set 7 | karratha
# Processing Record 3 of Set 7 | zhigansk
# City not found. Skipping...
# Processing Record 4 of Set 7 | khasan
# Processing Record 5 of Set 7 | pisco
# City not found. Skipping...
# Processing Record 6 of Set 7 | brokopondo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 7 | finspang
# Processing Record 8 of Set 7 | lebu
# Processing Record 9 of Set 7 | vigrestad
# Processing Record 10 of Set 7 | rexburg
# Processing Record 11 of Set 7 | roald
# Processing Record 12 of Set 7 | aklavik
# Processing Record 13 of Set 7 | bowen
# Processing Record 14 of Set 7 | oranjestad
# Processing Record 15 of Set 7 | waipawa
# Processing Record 16 of Set 7 | zhangye
# Processing Record 17 of Set 7 | kihei
# Processing Record 18 of Set 7 | kenai
# Processing Record 19 of Set 7 | priyutnoye
# Processing Record 20 of Set 7 | kalmunai
# City not found. Skipping...
# Processing Record 21 of Set 7 | mwense
# City not found. Skipping...
# Processing Record 22 of Set 7 | agadez
# Processing Record 23 of Set 7 | pontianak
# Processing Record 24 of Set 7 | ambulu
# Processing Record 25 of Set 7 | phetchaburi
# Processing Record 26 of Set 7 | beringovskiy
# Processing Record 27 of Set 7 | coahuayana
# Processing Record 28 of Set 7 | weligama
# Processing Record 29 of Set 7 | alofi
# Processing Record 30 of Set 7 | pokhara
# Processing Record 31 of Set 7 | mecca
# Processing Record 32 of Set 7 | zhurivka
# City not found. Skipping...
# Processing Record 33 of Set 7 | yar-sale
# Processing Record 34 of Set 7 | gore
# Processing Record 35 of Set 7 | asyut
# City not found. Skipping...
# Processing Record 36 of Set 7 | barguzin
# Processing Record 37 of Set 7 | kudeyevskiy
# Processing Record 38 of Set 7 | taoudenni
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 7 | atherton
# Processing Record 40 of Set 7 | kinna
# Processing Record 41 of Set 7 | krasnokamensk
# Processing Record 42 of Set 7 | bubaque
# Processing Record 43 of Set 7 | luganville
# Processing Record 44 of Set 7 | kazan
# Processing Record 45 of Set 7 | vestmannaeyjar
# Processing Record 46 of Set 7 | savannakhet
# Processing Record 47 of Set 7 | gamba
# Processing Record 48 of Set 7 | blagoveshchenka
# Processing Record 49 of Set 7 | vawkavysk
# City not found. Skipping...
# Processing Record 50 of Set 7 | guarapari
# Processing Record 1 of Set 8 | valparaiso
# City not found. Skipping...
# Processing Record 2 of Set 8 | liseleje
# City not found. Skipping...
# Processing Record 3 of Set 8 | pirgos
# Processing Record 4 of Set 8 | tilichiki
# Processing Record 5 of Set 8 | harper
# City not found. Skipping...
# Processing Record 6 of Set 8 | yarada
# Processing Record 7 of Set 8 | kahului
# Processing Record 8 of Set 8 | jalu
# Processing Record 9 of Set 8 | bethanien
# Processing Record 10 of Set 8 | roebourne
# Processing Record 11 of Set 8 | fjerritslev
# Processing Record 12 of Set 8 | torbay
# City not found. Skipping...
# Processing Record 13 of Set 8 | lazo
# Processing Record 14 of Set 8 | tonekabon
# Processing Record 15 of Set 8 | tommot
# Processing Record 16 of Set 8 | grand-santi
# Processing Record 17 of Set 8 | bathsheba
# Processing Record 18 of Set 8 | alexandria
# City not found. Skipping...
# Processing Record 19 of Set 8 | najran
# Processing Record 20 of Set 8 | berlevag
# City not found. Skipping...
# Processing Record 21 of Set 8 | vidim
# Processing Record 22 of Set 8 | camacha
# Processing Record 23 of Set 8 | sribne
# City not found. Skipping...
# Processing Record 24 of Set 8 | erenhot
# Processing Record 25 of Set 8 | vallenar
# Processing Record 26 of Set 8 | orocue
# Processing Record 27 of Set 8 | huoqiu
# Processing Record 28 of Set 8 | soyo
# Processing Record 29 of Set 8 | mocuba
# Processing Record 30 of Set 8 | worland
# Processing Record 31 of Set 8 | milkovo
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 8 | goma
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 8 | vostok
# Processing Record 34 of Set 8 | valera
# Processing Record 35 of Set 8 | dudinka
# City not found. Skipping...
# Processing Record 36 of Set 8 | dhidhdhoo
# Processing Record 37 of Set 8 | bilma
# Processing Record 38 of Set 8 | sandwick
# City not found. Skipping...
# Processing Record 39 of Set 8 | diadi
# Processing Record 40 of Set 8 | linkoping
# Processing Record 41 of Set 8 | talnakh
# City not found. Skipping...
# Processing Record 42 of Set 8 | vilcun
# City not found. Skipping...
# Processing Record 43 of Set 8 | birao
# City not found. Skipping...
# Processing Record 44 of Set 8 | bafq
# City not found. Skipping...
# Processing Record 45 of Set 8 | novopskov
# Processing Record 46 of Set 8 | baltiysk
# City not found. Skipping...
# Processing Record 47 of Set 8 | lehututu
# City not found. Skipping...
# Processing Record 48 of Set 8 | malayal
# Processing Record 49 of Set 8 | waddan
# Processing Record 50 of Set 8 | lompoc
# Processing Record 1 of Set 9 | okhotsk
# City not found. Skipping...
# Processing Record 2 of Set 9 | nogliki
# Processing Record 3 of Set 9 | kudligi
# Processing Record 4 of Set 9 | kavaratti
# City not found. Skipping...
# Processing Record 5 of Set 9 | slavonice
# Processing Record 6 of Set 9 | haapiti
# Processing Record 7 of Set 9 | alyangula
# Processing Record 8 of Set 9 | granville
# Processing Record 9 of Set 9 | manacapuru
# City not found. Skipping...
# Processing Record 10 of Set 9 | mahon
# City not found. Skipping...
# Processing Record 11 of Set 9 | port-gentil
# Processing Record 12 of Set 9 | seymchan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 9 | sola
# Processing Record 14 of Set 9 | nongstoin
# City not found. Skipping...
# Processing Record 15 of Set 9 | udalguri
# City not found. Skipping...
# Processing Record 16 of Set 9 | prescott
# Processing Record 17 of Set 9 | raudeberg
# City not found. Skipping...
# Processing Record 18 of Set 9 | kenora
# City not found. Skipping...
# Processing Record 19 of Set 9 | blagodatnoye
# City not found. Skipping...
# Processing Record 20 of Set 9 | sudbury
# Processing Record 21 of Set 9 | conakry
# City not found. Skipping...
# Processing Record 22 of Set 9 | waiuku
# Processing Record 23 of Set 9 | bandrele
# Processing Record 24 of Set 9 | bontang
# City not found. Skipping...
# Processing Record 25 of Set 9 | kralendijk
# City not found. Skipping...
# Processing Record 26 of Set 9 | samarai
# Processing Record 27 of Set 9 | tonantins
# Processing Record 28 of Set 9 | pringsewu
# City not found. Skipping...
# Processing Record 29 of Set 9 | barra
# City not found. Skipping...
# Processing Record 30 of Set 9 | waingapu
# City not found. Skipping...
# Processing Record 31 of Set 9 | alihe
# Processing Record 32 of Set 9 | lere
# City not found. Skipping...
# Processing Record 33 of Set 9 | lincoln
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 34 of Set 9 | jaypur
# Processing Record 35 of Set 9 | maamba
# City not found. Skipping...
# Processing Record 36 of Set 9 | ageyevo
# Processing Record 37 of Set 9 | corowa
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Set the dictionary for the DataFrame

raw_data = {
            "City": out_cities,
            "Cloudiness": cloudiness,
            "Country": country,
            "Date": date,
            "Humidity": humidity ,
            "Lat": latitude ,
            "Lng": longitude ,
            "Max Temp": max_temp ,
            "Wind Speed": wind_speed  
            
            }

# %%
# Convert to DataFrame and display the DataFrame
df_weather = pd.DataFrame(raw_data)
df_weather.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat      Lng  \
# 0        erzin          63      TR  1578268800        73  36.95    36.20
# 1   hambantota           7      LK  1578268800        80   6.12    81.12
# 2  tuktoyaktuk           0      CA  1578268800        98  69.44  -133.03
# 3      husavik          19      CA  1578268800        84  50.56   -96.99
# 4         bima          87      ID  1578268800        84  -8.45   118.73
#
#   Max Temp  Wind Speed
# 0    43.05        3.85
# 1    78.89       19.04
# 2   -20.00        4.34
# 3    13.77        7.74
# 4    79.34        1.19

# %%
# Save the output to a csv file "weather_data.csv"
df_weather.to_csv('Output_Data/weather_data.csv')

# %%
# Display the count of all the variables
df_weather.count()
# Out:
# City          437
# Cloudiness    437
# Country       437
# Date          437
# Humidity      437
# Lat           437
# Lng           437
# Max Temp      437
# Wind Speed    437
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from datetime import date
today_date = date.today().strftime('%m/%d/%Y') 
today_date
# Out:
# '01/05/2020'

# %%
plt.scatter(df_weather["Lat"], df_weather["Max Temp"], edgecolors = "black", facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature ("+ today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Max temp (F)")
#plt.xlim(-80,100)
#plt.ylim(min(df_weather["Max Temp"])-20 ,max(df_weather["Max Temp"])+20)
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

#plt.savefig("LatitudeVsTemperaturePlot.png")
plt.savefig("Output_Plots/LatitudeVsTemperaturePlot.pnge.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Humidity"], edgecolors = "black", facecolors="skyblue", s=20)
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title(" City Latitude vs. Humidity (" + today_date + ")" ) 
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsHumidityPlot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Cloudiness"], edgecolors = "black", facecolors="skyblue")
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title("City Latitude vs. Cloudiness (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsCloudinessPlot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Wind Speed"], edgecolors = "black", facecolors="skyblue")
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title("City Latitude vs. Wind Speed (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsWindSpeedPlot.png")
plt.show()
