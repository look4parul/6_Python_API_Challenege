# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import pprint
from datetime import date
from decimal import Decimal


# Import API key
import api_keys

# Import citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "Output_Data/weather_data.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for coordinates in lat_lngs:
    city = citipy.nearest_city(coordinates[0], coordinates[1]).city_name
# Replace spaces with "_" to create url correctly 
    city = city.replace(" ", "_")    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 631

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Openweather map API key
api_key = api_keys.api_key

# %%
#Create a function to get json value
def get_weather_json(city, api_key):
    url = "http://api.openweathermap.org/data/2.5/forecast"
    r = requests.get(url, params={
        "appid": api_key,
        "q": city,
        "units": "imperial"
    })
    if r.status_code ==200:
        r_json = r.json()
        return r_json
    else:
        return None

# %%
# Print the output json values
pprint.pprint(get_weather_json(city,api_key),indent =4)
# Out:
# {   'city': {   'coord': {'lat': -18.1305, 'lon': 30.146},
#                 'country': 'ZW',
#                 'id': 894239,
#                 'name': 'Chegutu',
#                 'population': 47294,
#                 'sunrise': 1578367815,
#                 'sunset': 1578415206,
#                 'timezone': 7200},
#     'cnt': 40,
#     'cod': '200',
#     'list': [   {   'clouds': {'all': 96},
#                     'dt': 1578376800,
#                     'dt_txt': '2020-01-07 06:00:00',
#                     'main': {   'feels_like': 78.04,
#                                 'grnd_level': 891,
#                                 'humidity': 62,
#                                 'pressure': 1012,
#                                 'sea_level': 1012,
#                                 'temp': 77.09,
#                                 'temp_kf': 0,
#                                 'temp_max': 77.09,
#                                 'temp_min': 77.09},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 7, 'speed': 6.24}},
#                 {   'clouds': {'all': 31},
#                     'dt': 1578387600,
#                     'dt_txt': '2020-01-07 09:00:00',
#                     'main': {   'feels_like': 84.88,
#                                 'grnd_level': 889,
#                                 'humidity': 42,
#                                 'pressure': 1010,
#                                 'sea_level': 1010,
#                                 'temp': 86.49,
#                                 'temp_kf': 0,
#                                 'temp_max': 86.49,
#                                 'temp_min': 86.49},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'scattered clouds',
#                                        'icon': '03d',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 14, 'speed': 9.08}},
#                 {   'clouds': {'all': 42},
#                     'dt': 1578398400,
#                     'dt_txt': '2020-01-07 12:00:00',
#                     'main': {   'feels_like': 87.98,
#                                 'grnd_level': 888,
#                                 'humidity': 33,
#                                 'pressure': 1008,
#                                 'sea_level': 1008,
#                                 'temp': 89.91,
#                                 'temp_kf': 0,
#                                 'temp_max': 89.91,
#                                 'temp_min': 89.91},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'scattered clouds',
#                                        'icon': '03d',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 25, 'speed': 7.27}},
#                 {   'clouds': {'all': 1},
#                     'dt': 1578409200,
#                     'dt_txt': '2020-01-07 15:00:00',
#                     'main': {   'feels_like': 86,
#                                 'grnd_level': 886,
#                                 'humidity': 36,
#                                 'pressure': 1007,
#                                 'sea_level': 1007,
#                                 'temp': 88.07,
#                                 'temp_kf': 0,
#                                 'temp_max': 88.07,
#                                 'temp_min': 88.07},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'clear sky',
#                                        'icon': '01d',
#                                        'id': 800,
#                                        'main': 'Clear'}],
#                     'wind': {'deg': 359, 'speed': 8.03}},
#                 {   'clouds': {'all': 14},
#                     'dt': 1578420000,
#                     'dt_txt': '2020-01-07 18:00:00',
#                     'main': {   'feels_like': 77.61,
#                                 'grnd_level': 889,
#                                 'humidity': 74,
#                                 'pressure': 1010,
#                                 'sea_level': 1010,
#                                 'temp': 73.51,
#                                 'temp_kf': 0,
#                                 'temp_max': 73.51,
#                                 'temp_min': 73.51},
#                     'rain': {'3h': 1.94},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 160, 'speed': 1.88}},
#                 {   'clouds': {'all': 67},
#                     'dt': 1578430800,
#                     'dt_txt': '2020-01-07 21:00:00',
#                     'main': {   'feels_like': 76.73,
#                                 'grnd_level': 890,
#                                 'humidity': 82,
#                                 'pressure': 1012,
#                                 'sea_level': 1012,
#                                 'temp': 71.69,
#                                 'temp_kf': 0,
#                                 'temp_max': 71.69,
#                                 'temp_min': 71.69},
#                     'rain': {'3h': 2.38},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 279, 'speed': 1.14}},
#                 {   'clouds': {'all': 72},
#                     'dt': 1578441600,
#                     'dt_txt': '2020-01-08 00:00:00',
#                     'main': {   'feels_like': 71.91,
#                                 'grnd_level': 890,
#                                 'humidity': 84,
#                                 'pressure': 1011,
#                                 'sea_level': 1011,
#                                 'temp': 69.03,
#                                 'temp_kf': 0,
#                                 'temp_max': 69.03,
#                                 'temp_min': 69.03},
#                     'rain': {'3h': 0.13},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 19, 'speed': 3.49}},
#                 {   'clouds': {'all': 66},
#                     'dt': 1578452400,
#                     'dt_txt': '2020-01-08 03:00:00',
#                     'main': {   'feels_like': 71.6,
#                                 'grnd_level': 890,
#                                 'humidity': 86,
#                                 'pressure': 1012,
#                                 'sea_level': 1012,
#                                 'temp': 68.16,
#                                 'temp_kf': 0,
#                                 'temp_max': 68.16,
#                                 'temp_min': 68.16},
#                     'rain': {'3h': 0.19},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 54, 'speed': 2.37}},
#                 {   'clouds': {'all': 52},
#                     'dt': 1578463200,
#                     'dt_txt': '2020-01-08 06:00:00',
#                     'main': {   'feels_like': 77.59,
#                                 'grnd_level': 892,
#                                 'humidity': 75,
#                                 'pressure': 1013,
#                                 'sea_level': 1013,
#                                 'temp': 74.16,
#                                 'temp_kf': 0,
#                                 'temp_max': 74.16,
#                                 'temp_min': 74.16},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 61, 'speed': 3.83}},
#                 {   'clouds': {'all': 37},
#                     'dt': 1578474000,
#                     'dt_txt': '2020-01-08 09:00:00',
#                     'main': {   'feels_like': 89.69,
#                                 'grnd_level': 890,
#                                 'humidity': 40,
#                                 'pressure': 1011,
#                                 'sea_level': 1011,
#                                 'temp': 88.68,
#                                 'temp_kf': 0,
#                                 'temp_max': 88.68,
#                                 'temp_min': 88.68},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'scattered clouds',
#                                        'icon': '03d',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 0, 'speed': 4.83}},
#                 {   'clouds': {'all': 68},
#                     'dt': 1578484800,
#                     'dt_txt': '2020-01-08 12:00:00',
#                     'main': {   'feels_like': 86.72,
#                                 'grnd_level': 888,
#                                 'humidity': 45,
#                                 'pressure': 1009,
#                                 'sea_level': 1009,
#                                 'temp': 85.71,
#                                 'temp_kf': 0,
#                                 'temp_max': 85.71,
#                                 'temp_min': 85.71},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 310, 'speed': 5.3}},
#                 {   'clouds': {'all': 97},
#                     'dt': 1578495600,
#                     'dt_txt': '2020-01-08 15:00:00',
#                     'main': {   'feels_like': 81.3,
#                                 'grnd_level': 887,
#                                 'humidity': 59,
#                                 'pressure': 1008,
#                                 'sea_level': 1008,
#                                 'temp': 80.94,
#                                 'temp_kf': 0,
#                                 'temp_max': 80.94,
#                                 'temp_min': 80.94},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 336, 'speed': 8.95}},
#                 {   'clouds': {'all': 98},
#                     'dt': 1578506400,
#                     'dt_txt': '2020-01-08 18:00:00',
#                     'main': {   'feels_like': 76.48,
#                                 'grnd_level': 889,
#                                 'humidity': 78,
#                                 'pressure': 1011,
#                                 'sea_level': 1011,
#                                 'temp': 73.17,
#                                 'temp_kf': 0,
#                                 'temp_max': 73.17,
#                                 'temp_min': 73.17},
#                     'rain': {'3h': 2.25},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 8, 'speed': 4.21}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578517200,
#                     'dt_txt': '2020-01-08 21:00:00',
#                     'main': {   'feels_like': 74.89,
#                                 'grnd_level': 890,
#                                 'humidity': 87,
#                                 'pressure': 1012,
#                                 'sea_level': 1012,
#                                 'temp': 70.45,
#                                 'temp_kf': 0,
#                                 'temp_max': 70.45,
#                                 'temp_min': 70.45},
#                     'rain': {'3h': 4.19},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'moderate rain',
#                                        'icon': '10n',
#                                        'id': 501,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 17, 'speed': 2.57}},
#                 {   'clouds': {'all': 96},
#                     'dt': 1578528000,
#                     'dt_txt': '2020-01-09 00:00:00',
#                     'main': {   'feels_like': 72.48,
#                                 'grnd_level': 889,
#                                 'humidity': 89,
#                                 'pressure': 1010,
#                                 'sea_level': 1010,
#                                 'temp': 68.9,
#                                 'temp_kf': 0,
#                                 'temp_max': 68.9,
#                                 'temp_min': 68.9},
#                     'rain': {'3h': 0.25},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 39, 'speed': 3.44}},
#                 {   'clouds': {'all': 83},
#                     'dt': 1578538800,
#                     'dt_txt': '2020-01-09 03:00:00',
#                     'main': {   'feels_like': 71.64,
#                                 'grnd_level': 889,
#                                 'humidity': 89,
#                                 'pressure': 1011,
#                                 'sea_level': 1011,
#                                 'temp': 68.04,
#                                 'temp_kf': 0,
#                                 'temp_max': 68.04,
#                                 'temp_min': 68.04},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04n',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 58, 'speed': 2.75}},
#                 {   'clouds': {'all': 86},
#                     'dt': 1578549600,
#                     'dt_txt': '2020-01-09 06:00:00',
#                     'main': {   'feels_like': 76.01,
#                                 'grnd_level': 891,
#                                 'humidity': 83,
#                                 'pressure': 1012,
#                                 'sea_level': 1012,
#                                 'temp': 71.55,
#                                 'temp_kf': 0,
#                                 'temp_max': 71.55,
#                                 'temp_min': 71.55},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 22, 'speed': 2.33}},
#                 {   'clouds': {'all': 37},
#                     'dt': 1578560400,
#                     'dt_txt': '2020-01-09 09:00:00',
#                     'main': {   'feels_like': 90.03,
#                                 'grnd_level': 889,
#                                 'humidity': 46,
#                                 'pressure': 1009,
#                                 'sea_level': 1009,
#                                 'temp': 87.39,
#                                 'temp_kf': 0,
#                                 'temp_max': 87.39,
#                                 'temp_min': 87.39},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'scattered clouds',
#                                        'icon': '03d',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 319, 'speed': 3.96}},
#                 {   'clouds': {'all': 39},
#                     'dt': 1578571200,
#                     'dt_txt': '2020-01-09 12:00:00',
#                     'main': {   'feels_like': 96.98,
#                                 'grnd_level': 886,
#                                 'humidity': 34,
#                                 'pressure': 1007,
#                                 'sea_level': 1007,
#                                 'temp': 94.6,
#                                 'temp_kf': 0,
#                                 'temp_max': 94.6,
#                                 'temp_min': 94.6},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'scattered clouds',
#                                        'icon': '03d',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 319, 'speed': 2.84}},
#                 {   'clouds': {'all': 84},
#                     'dt': 1578582000,
#                     'dt_txt': '2020-01-09 15:00:00',
#                     'main': {   'feels_like': 81.82,
#                                 'grnd_level': 885,
#                                 'humidity': 53,
#                                 'pressure': 1005,
#                                 'sea_level': 1005,
#                                 'temp': 83.1,
#                                 'temp_kf': 0,
#                                 'temp_max': 83.1,
#                                 'temp_min': 83.1},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 317, 'speed': 11.03}},
#                 {   'clouds': {'all': 82},
#                     'dt': 1578592800,
#                     'dt_txt': '2020-01-09 18:00:00',
#                     'main': {   'feels_like': 70.45,
#                                 'grnd_level': 887,
#                                 'humidity': 97,
#                                 'pressure': 1009,
#                                 'sea_level': 1009,
#                                 'temp': 69.01,
#                                 'temp_kf': 0,
#                                 'temp_max': 69.01,
#                                 'temp_min': 69.01},
#                     'rain': {'3h': 27.06},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'heavy intensity rain',
#                                        'icon': '10n',
#                                        'id': 502,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 306, 'speed': 9.35}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578603600,
#                     'dt_txt': '2020-01-09 21:00:00',
#                     'main': {   'feels_like': 77.05,
#                                 'grnd_level': 889,
#                                 'humidity': 92,
#                                 'pressure': 1010,
#                                 'sea_level': 1010,
#                                 'temp': 71.02,
#                                 'temp_kf': 0,
#                                 'temp_max': 71.02,
#                                 'temp_min': 71.02},
#                     'rain': {'3h': 5.19},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'moderate rain',
#                                        'icon': '10n',
#                                        'id': 501,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 13, 'speed': 1.61}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578614400,
#                     'dt_txt': '2020-01-10 00:00:00',
#                     'main': {   'feels_like': 72.61,
#                                 'grnd_level': 888,
#                                 'humidity': 94,
#                                 'pressure': 1010,
#                                 'sea_level': 1010,
#                                 'temp': 68.59,
#                                 'temp_kf': 0,
#                                 'temp_max': 68.59,
#                                 'temp_min': 68.59},
#                     'rain': {'3h': 1.12},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 331, 'speed': 3.69}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578625200,
#                     'dt_txt': '2020-01-10 03:00:00',
#                     'main': {   'feels_like': 72.3,
#                                 'grnd_level': 889,
#                                 'humidity': 96,
#                                 'pressure': 1011,
#                                 'sea_level': 1011,
#                                 'temp': 67.21,
#                                 'temp_kf': 0,
#                                 'temp_max': 67.21,
#                                 'temp_min': 67.21},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 0, 'speed': 1.14}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578636000,
#                     'dt_txt': '2020-01-10 06:00:00',
#                     'main': {   'feels_like': 76.91,
#                                 'grnd_level': 890,
#                                 'humidity': 82,
#                                 'pressure': 1012,
#                                 'sea_level': 1012,
#                                 'temp': 72.75,
#                                 'temp_kf': 0,
#                                 'temp_max': 72.75,
#                                 'temp_min': 72.75},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 38, 'speed': 3.53}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578646800,
#                     'dt_txt': '2020-01-10 09:00:00',
#                     'main': {   'feels_like': 82.31,
#                                 'grnd_level': 890,
#                                 'humidity': 68,
#                                 'pressure': 1010,
#                                 'sea_level': 1010,
#                                 'temp': 78.69,
#                                 'temp_kf': 0,
#                                 'temp_max': 78.69,
#                                 'temp_min': 78.69},
#                     'rain': {'3h': 3.19},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'moderate rain',
#                                        'icon': '10d',
#                                        'id': 501,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 358, 'speed': 4.74}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578657600,
#                     'dt_txt': '2020-01-10 12:00:00',
#                     'main': {   'feels_like': 89.15,
#                                 'grnd_level': 887,
#                                 'humidity': 44,
#                                 'pressure': 1007,
#                                 'sea_level': 1007,
#                                 'temp': 86.94,
#                                 'temp_kf': 0,
#                                 'temp_max': 86.94,
#                                 'temp_min': 86.94},
#                     'rain': {'3h': 0.87},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10d',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 116, 'speed': 3.49}},
#                 {   'clouds': {'all': 88},
#                     'dt': 1578668400,
#                     'dt_txt': '2020-01-10 15:00:00',
#                     'main': {   'feels_like': 86.11,
#                                 'grnd_level': 886,
#                                 'humidity': 47,
#                                 'pressure': 1006,
#                                 'sea_level': 1006,
#                                 'temp': 85.32,
#                                 'temp_kf': 0,
#                                 'temp_max': 85.32,
#                                 'temp_min': 85.32},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 67, 'speed': 6.33}},
#                 {   'clouds': {'all': 49},
#                     'dt': 1578679200,
#                     'dt_txt': '2020-01-10 18:00:00',
#                     'main': {   'feels_like': 75.52,
#                                 'grnd_level': 888,
#                                 'humidity': 74,
#                                 'pressure': 1009,
#                                 'sea_level': 1009,
#                                 'temp': 73.33,
#                                 'temp_kf': 0,
#                                 'temp_max': 73.33,
#                                 'temp_min': 73.33},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'scattered clouds',
#                                        'icon': '03n',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 349, 'speed': 5.12}},
#                 {   'clouds': {'all': 73},
#                     'dt': 1578690000,
#                     'dt_txt': '2020-01-10 21:00:00',
#                     'main': {   'feels_like': 75.02,
#                                 'grnd_level': 890,
#                                 'humidity': 84,
#                                 'pressure': 1012,
#                                 'sea_level': 1012,
#                                 'temp': 70.05,
#                                 'temp_kf': 0,
#                                 'temp_max': 70.05,
#                                 'temp_min': 70.05},
#                     'rain': {'3h': 0.44},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 61, 'speed': 0.56}},
#                 {   'clouds': {'all': 85},
#                     'dt': 1578700800,
#                     'dt_txt': '2020-01-11 00:00:00',
#                     'main': {   'feels_like': 69.73,
#                                 'grnd_level': 890,
#                                 'humidity': 88,
#                                 'pressure': 1012,
#                                 'sea_level': 1012,
#                                 'temp': 67.86,
#                                 'temp_kf': 0,
#                                 'temp_max': 67.86,
#                                 'temp_min': 67.86},
#                     'rain': {'3h': 0.37},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 106, 'speed': 5.44}},
#                 {   'clouds': {'all': 86},
#                     'dt': 1578711600,
#                     'dt_txt': '2020-01-11 03:00:00',
#                     'main': {   'feels_like': 67.46,
#                                 'grnd_level': 891,
#                                 'humidity': 89,
#                                 'pressure': 1013,
#                                 'sea_level': 1013,
#                                 'temp': 65.91,
#                                 'temp_kf': 0,
#                                 'temp_max': 65.91,
#                                 'temp_min': 65.91},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04n',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 95, 'speed': 4.83}},
#                 {   'clouds': {'all': 79},
#                     'dt': 1578722400,
#                     'dt_txt': '2020-01-11 06:00:00',
#                     'main': {   'feels_like': 75.92,
#                                 'grnd_level': 892,
#                                 'humidity': 74,
#                                 'pressure': 1014,
#                                 'sea_level': 1014,
#                                 'temp': 73.17,
#                                 'temp_kf': 0,
#                                 'temp_max': 73.17,
#                                 'temp_min': 73.17},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 100, 'speed': 4.03}},
#                 {   'clouds': {'all': 46},
#                     'dt': 1578733200,
#                     'dt_txt': '2020-01-11 09:00:00',
#                     'main': {   'feels_like': 87.69,
#                                 'grnd_level': 891,
#                                 'humidity': 48,
#                                 'pressure': 1012,
#                                 'sea_level': 1012,
#                                 'temp': 85.12,
#                                 'temp_kf': 0,
#                                 'temp_max': 85.12,
#                                 'temp_min': 85.12},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'scattered clouds',
#                                        'icon': '03d',
#                                        'id': 802,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 113, 'speed': 3.47}},
#                 {   'clouds': {'all': 70},
#                     'dt': 1578744000,
#                     'dt_txt': '2020-01-11 12:00:00',
#                     'main': {   'feels_like': 87.19,
#                                 'grnd_level': 889,
#                                 'humidity': 46,
#                                 'pressure': 1009,
#                                 'sea_level': 1009,
#                                 'temp': 84.97,
#                                 'temp_kf': 0,
#                                 'temp_max': 84.97,
#                                 'temp_min': 84.97},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'broken clouds',
#                                        'icon': '04d',
#                                        'id': 803,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 16, 'speed': 3.13}},
#                 {   'clouds': {'all': 87},
#                     'dt': 1578754800,
#                     'dt_txt': '2020-01-11 15:00:00',
#                     'main': {   'feels_like': 87.49,
#                                 'grnd_level': 888,
#                                 'humidity': 50,
#                                 'pressure': 1009,
#                                 'sea_level': 1009,
#                                 'temp': 83.61,
#                                 'temp_kf': 0,
#                                 'temp_max': 83.61,
#                                 'temp_min': 83.61},
#                     'sys': {'pod': 'd'},
#                     'weather': [   {   'description': 'overcast clouds',
#                                        'icon': '04d',
#                                        'id': 804,
#                                        'main': 'Clouds'}],
#                     'wind': {'deg': 221, 'speed': 0.96}},
#                 {   'clouds': {'all': 86},
#                     'dt': 1578765600,
#                     'dt_txt': '2020-01-11 18:00:00',
#                     'main': {   'feels_like': 70.21,
#                                 'grnd_level': 890,
#                                 'humidity': 91,
#                                 'pressure': 1012,
#                                 'sea_level': 1012,
#                                 'temp': 67.96,
#                                 'temp_kf': 0,
#                                 'temp_max': 67.96,
#                                 'temp_min': 67.96},
#                     'rain': {'3h': 11},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'moderate rain',
#                                        'icon': '10n',
#                                        'id': 501,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 326, 'speed': 5.57}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578776400,
#                     'dt_txt': '2020-01-11 21:00:00',
#                     'main': {   'feels_like': 74.95,
#                                 'grnd_level': 892,
#                                 'humidity': 88,
#                                 'pressure': 1014,
#                                 'sea_level': 1014,
#                                 'temp': 70.25,
#                                 'temp_kf': 0,
#                                 'temp_max': 70.25,
#                                 'temp_min': 70.25},
#                     'rain': {'3h': 2},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 138, 'speed': 2.26}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578787200,
#                     'dt_txt': '2020-01-12 00:00:00',
#                     'main': {   'feels_like': 72.97,
#                                 'grnd_level': 891,
#                                 'humidity': 88,
#                                 'pressure': 1013,
#                                 'sea_level': 1013,
#                                 'temp': 69.31,
#                                 'temp_kf': 0,
#                                 'temp_max': 69.31,
#                                 'temp_min': 69.31},
#                     'rain': {'3h': 0.75},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 55, 'speed': 3.38}},
#                 {   'clouds': {'all': 100},
#                     'dt': 1578798000,
#                     'dt_txt': '2020-01-12 03:00:00',
#                     'main': {   'feels_like': 72.07,
#                                 'grnd_level': 892,
#                                 'humidity': 94,
#                                 'pressure': 1014,
#                                 'sea_level': 1014,
#                                 'temp': 67.71,
#                                 'temp_kf': 0,
#                                 'temp_max': 67.71,
#                                 'temp_min': 67.71},
#                     'rain': {'3h': 1.19},
#                     'sys': {'pod': 'n'},
#                     'weather': [   {   'description': 'light rain',
#                                        'icon': '10n',
#                                        'id': 500,
#                                        'main': 'Rain'}],
#                     'wind': {'deg': 99, 'speed': 2.37}}],
#     'message': 0}

# %%
# Declare the list of elements for data frame
out_cities = []
cloudiness = []
country = []
date = []
humidity = []
latitude = []
longitude = []
max_temp = []
wind_speed = []
date_yyyymmdd = [] # Added new field to get date in format (YYYY-MM-DD)

# %%
# Set the initial values for set and record variables
record = 0
set = 1

# Print the output as per the required output
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

for in_city in cities:
    response = get_weather_json(in_city.replace(" ", "_"), api_key)
    
    if response:
        # Append the values for all DataFrame variables 
        cloudiness.append(response['list'][0]['clouds']['all'])
        city_data = response['city']
        country.append(city_data['country'])
        date.append(response['list'][0]["dt"])
        date_yyyymmdd.append(response['list'][0]["dt_txt"])
        humidity.append(response['list'][0]['main']['humidity'])
        latitude.append(Decimal(city_data['coord']['lat']).quantize(Decimal(10) ** -2  ))
        longitude.append(Decimal(city_data['coord']['lon']).quantize(Decimal(10) ** -2  ))
        max_temp.append(Decimal(response['list'][0]['main']['temp_max']).quantize(Decimal(10) ** -2  ))
        wind_speed.append(response['list'][0]['wind']['speed'])
        # Check to increment the value of set as per the required output and append the cities for DataFrame
        if record > 49:
            record = 1
            set += 1
            out_cities.append(in_city)
        else:
            record += 1
            out_cities.append(in_city)
        print(f"Processing Record {record} of Set {set} | {in_city}")
    # Check if the city is not in the list
    else:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Complete\n------------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 of Set 1 | huaraz
# City not found. Skipping...
# Processing Record 2 of Set 1 | albany
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | esperance
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 1 | bluff
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 1 | kodiak
# City not found. Skipping...
# Processing Record 8 of Set 1 | vardo
# Processing Record 9 of Set 1 | auki
# City not found. Skipping...
# Processing Record 10 of Set 1 | butaritari
# Processing Record 11 of Set 1 | luderitz
# Processing Record 12 of Set 1 | supe
# Processing Record 13 of Set 1 | harboore
# Processing Record 14 of Set 1 | hilo
# City not found. Skipping...
# Processing Record 15 of Set 1 | klaksvik
# Processing Record 16 of Set 1 | faya
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | willowmore
# City not found. Skipping...
# Processing Record 20 of Set 1 | monrovia
# Processing Record 21 of Set 1 | joacaba
# City not found. Skipping...
# Processing Record 22 of Set 1 | kuusamo
# Processing Record 23 of Set 1 | rocha
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 1 | vaini
# Processing Record 25 of Set 1 | hithadhoo
# City not found. Skipping...
# Processing Record 26 of Set 1 | palmer
# Processing Record 27 of Set 1 | avarua
# City not found. Skipping...
# Processing Record 28 of Set 1 | constantine
# Processing Record 29 of Set 1 | narasannapeta
# Processing Record 30 of Set 1 | shingu
# Processing Record 31 of Set 1 | martinsburg
# Processing Record 32 of Set 1 | evensk
# Processing Record 33 of Set 1 | tuktoyaktuk
# Processing Record 34 of Set 1 | padang
# Processing Record 35 of Set 1 | grants
# Processing Record 36 of Set 1 | souillac
# Processing Record 37 of Set 1 | sola
# Processing Record 38 of Set 1 | floresta
# Processing Record 39 of Set 1 | tartagal
# Processing Record 40 of Set 1 | castro
# City not found. Skipping...
# Processing Record 41 of Set 1 | laguna
# Processing Record 42 of Set 1 | khandyga
# Processing Record 43 of Set 1 | dolores
# Processing Record 44 of Set 1 | lasa
# Processing Record 45 of Set 1 | iqaluit
# Processing Record 46 of Set 1 | muisne
# Processing Record 47 of Set 1 | barrow
# Processing Record 48 of Set 1 | zonguldak
# Processing Record 49 of Set 1 | hobart
# Processing Record 50 of Set 1 | fortuna
# Processing Record 1 of Set 2 | salinas
# Processing Record 2 of Set 2 | ilulissat
# Processing Record 3 of Set 2 | gorontalo
# Processing Record 4 of Set 2 | ushuaia
# Processing Record 5 of Set 2 | xining
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | rincon
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 8 of Set 2 | cidreira
# City not found. Skipping...
# Processing Record 9 of Set 2 | aykhal
# Processing Record 10 of Set 2 | upernavik
# Processing Record 11 of Set 2 | mataura
# Processing Record 12 of Set 2 | carutapera
# Processing Record 13 of Set 2 | stepnyak
# Processing Record 14 of Set 2 | bocholt
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | dikson
# Processing Record 17 of Set 2 | tubigan
# Processing Record 18 of Set 2 | coquimbo
# City not found. Skipping...
# Processing Record 19 of Set 2 | mufumbwe
# Processing Record 20 of Set 2 | masty
# Processing Record 21 of Set 2 | kutum
# Processing Record 22 of Set 2 | vanimo
# Processing Record 23 of Set 2 | alofi
# City not found. Skipping...
# Processing Record 24 of Set 2 | kjopsvik
# City not found. Skipping...
# Processing Record 25 of Set 2 | tura
# Processing Record 26 of Set 2 | paramonga
# Processing Record 27 of Set 2 | sidney
# Processing Record 28 of Set 2 | hella
# City not found. Skipping...
# Processing Record 29 of Set 2 | mitsamiouli
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 2 | gbarnga
# Processing Record 31 of Set 2 | saskylakh
# Processing Record 32 of Set 2 | jalu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 2 | hermanus
# Processing Record 34 of Set 2 | emerald
# City not found. Skipping...
# Processing Record 35 of Set 2 | beringovskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 2 | mahenge
# Processing Record 37 of Set 2 | coahuayana
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 2 | kaitangata
# Processing Record 39 of Set 2 | kruisfontein
# City not found. Skipping...
# Processing Record 40 of Set 2 | bandarbeyla
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 2 | rawatsar
# Processing Record 42 of Set 2 | husavik
# Processing Record 43 of Set 2 | severo-kurilsk
# Processing Record 44 of Set 2 | avera
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | ushtobe
# Processing Record 47 of Set 2 | lebu
# Processing Record 48 of Set 2 | kapaa
# Processing Record 49 of Set 2 | katsuura
# Processing Record 50 of Set 2 | sitka
# Processing Record 1 of Set 3 | hami
# City not found. Skipping...
# Processing Record 2 of Set 3 | mackay
# Processing Record 3 of Set 3 | nadvoitsy
# Processing Record 4 of Set 3 | tessalit
# City not found. Skipping...
# Processing Record 5 of Set 3 | marawi
# City not found. Skipping...
# Processing Record 6 of Set 3 | provideniya
# City not found. Skipping...
# Processing Record 7 of Set 3 | kudahuvadhoo
# Processing Record 8 of Set 3 | yurty
# City not found. Skipping...
# Processing Record 9 of Set 3 | tiarei
# Processing Record 10 of Set 3 | riohacha
# Processing Record 11 of Set 3 | codrington
# Processing Record 12 of Set 3 | yafran
# Processing Record 13 of Set 3 | juegang
# Processing Record 14 of Set 3 | virden
# Processing Record 15 of Set 3 | yulara
# City not found. Skipping...
# Processing Record 16 of Set 3 | atuona
# City not found. Skipping...
# Processing Record 17 of Set 3 | nikolskoye
# Processing Record 18 of Set 3 | sinnamary
# City not found. Skipping...
# Processing Record 19 of Set 3 | tuatapere
# Processing Record 20 of Set 3 | jamestown
# Processing Record 21 of Set 3 | qinnan
# Processing Record 22 of Set 3 | solwezi
# Processing Record 23 of Set 3 | carnarvon
# Processing Record 24 of Set 3 | hobyo
# Processing Record 25 of Set 3 | qaanaaq
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 26 of Set 3 | faanui
# Processing Record 27 of Set 3 | hirara
# City not found. Skipping...
# Processing Record 28 of Set 3 | lorengau
# Processing Record 29 of Set 3 | touros
# Processing Record 30 of Set 3 | mahibadhoo
# City not found. Skipping...
# Processing Record 31 of Set 3 | kant
# City not found. Skipping...
# Processing Record 32 of Set 3 | saint-philippe
# Processing Record 33 of Set 3 | villanueva
# Processing Record 34 of Set 3 | voh
# City not found. Skipping...
# Processing Record 35 of Set 3 | airai
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 3 | pisco
# Processing Record 37 of Set 3 | bethel
# Processing Record 38 of Set 3 | nuuk
# Processing Record 39 of Set 3 | agirish
# Processing Record 40 of Set 3 | ahuimanu
# Processing Record 41 of Set 3 | japura
# City not found. Skipping...
# Processing Record 42 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 3 | mehamn
# Processing Record 44 of Set 3 | port-cartier
# Processing Record 45 of Set 3 | ust-nera
# Processing Record 46 of Set 3 | vermilion
# City not found. Skipping...
# Processing Record 47 of Set 3 | adrar
# Processing Record 48 of Set 3 | acari
# City not found. Skipping...
# Processing Record 49 of Set 3 | ahipara
# Processing Record 50 of Set 3 | muros
# Processing Record 1 of Set 4 | pinega
# Processing Record 2 of Set 4 | torbay
# Processing Record 3 of Set 4 | saldanha
# City not found. Skipping...
# Processing Record 4 of Set 4 | horsham
# City not found. Skipping...
# Processing Record 5 of Set 4 | khatanga
# City not found. Skipping...
# Processing Record 6 of Set 4 | college
# Processing Record 7 of Set 4 | pascagoula
# Processing Record 8 of Set 4 | yarmouth
# Processing Record 9 of Set 4 | pahrump
# Processing Record 10 of Set 4 | kaltasy
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 4 | ghatal
# Processing Record 12 of Set 4 | tabou
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 13 of Set 4 | ulladulla
# Processing Record 14 of Set 4 | kahului
# Processing Record 15 of Set 4 | chuy
# Processing Record 16 of Set 4 | shenzhen
# Processing Record 17 of Set 4 | acapulco
# City not found. Skipping...
# Processing Record 18 of Set 4 | atasu
# Processing Record 19 of Set 4 | kavieng
# City not found. Skipping...
# Processing Record 20 of Set 4 | gemena
# City not found. Skipping...
# Processing Record 21 of Set 4 | hofn
# Processing Record 22 of Set 4 | mozarlandia
# City not found. Skipping...
# Processing Record 23 of Set 4 | manta
# Processing Record 24 of Set 4 | belmonte
# Processing Record 25 of Set 4 | geraldton
# City not found. Skipping...
# Processing Record 26 of Set 4 | darhan
# Processing Record 27 of Set 4 | ancud
# City not found. Skipping...
# Processing Record 28 of Set 4 | maamba
# Processing Record 29 of Set 4 | narsaq
# Processing Record 30 of Set 4 | sirari
# Processing Record 31 of Set 4 | wonthaggi
# City not found. Skipping...
# Processing Record 32 of Set 4 | sabinov
# Processing Record 33 of Set 4 | stolin
# Processing Record 34 of Set 4 | fairbanks
# Processing Record 35 of Set 4 | karpogory
# Processing Record 36 of Set 4 | requena
# Processing Record 37 of Set 4 | hualmay
# City not found. Skipping...
# Processing Record 38 of Set 4 | dzheyrakh
# Processing Record 39 of Set 4 | kiruna
# City not found. Skipping...
# Processing Record 40 of Set 4 | pedernales
# Processing Record 41 of Set 4 | hambantota
# Processing Record 42 of Set 4 | hovd
# Processing Record 43 of Set 4 | anloga
# City not found. Skipping...
# Processing Record 44 of Set 4 | chara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 45 of Set 4 | sept-iles
# Processing Record 46 of Set 4 | chokurdakh
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 47 of Set 4 | ocos
# Processing Record 48 of Set 4 | deniliquin
# Processing Record 49 of Set 4 | dukat
# Processing Record 50 of Set 4 | khani
# Processing Record 1 of Set 5 | tefe
# City not found. Skipping...
# Processing Record 2 of Set 5 | wum
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 5 | ola
# City not found. Skipping...
# Processing Record 4 of Set 5 | sorong
# Processing Record 5 of Set 5 | trapani
# Processing Record 6 of Set 5 | gat
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 5 | doha
# Processing Record 8 of Set 5 | karasjok
# City not found. Skipping...
# Processing Record 9 of Set 5 | pevek
# Processing Record 10 of Set 5 | klichka
# Processing Record 11 of Set 5 | matara
# Processing Record 12 of Set 5 | flinders
# Processing Record 13 of Set 5 | rawson
# City not found. Skipping...
# Processing Record 14 of Set 5 | arlit
# Processing Record 15 of Set 5 | leningradskiy
# Processing Record 16 of Set 5 | teguise
# Processing Record 17 of Set 5 | mandalgovi
# Processing Record 18 of Set 5 | cairns
# City not found. Skipping...
# Processing Record 19 of Set 5 | wenshang
# Processing Record 20 of Set 5 | zhigansk
# Processing Record 21 of Set 5 | pandan
# Processing Record 22 of Set 5 | soyo
# Processing Record 23 of Set 5 | dunedin
# Processing Record 24 of Set 5 | lompoc
# Processing Record 25 of Set 5 | tasiilaq
# Processing Record 26 of Set 5 | cefalu
# Processing Record 27 of Set 5 | vitoria
# Processing Record 28 of Set 5 | lagoa
# Processing Record 29 of Set 5 | talara
# Processing Record 30 of Set 5 | victoria
# Processing Record 31 of Set 5 | mindelo
# City not found. Skipping...
# Processing Record 32 of Set 5 | buraydah
# Processing Record 33 of Set 5 | mangrol
# Processing Record 34 of Set 5 | butka
# Processing Record 35 of Set 5 | fengrun
# Processing Record 36 of Set 5 | sisimiut
# Processing Record 37 of Set 5 | dzaoudzi
# Processing Record 38 of Set 5 | capoterra
# Processing Record 39 of Set 5 | amboasary
# Processing Record 40 of Set 5 | muana
# City not found. Skipping...
# Processing Record 41 of Set 5 | namatanai
# Processing Record 42 of Set 5 | jinchang
# Processing Record 43 of Set 5 | dongsheng
# Processing Record 44 of Set 5 | jiuquan
# Processing Record 45 of Set 5 | bend
# Processing Record 46 of Set 5 | sosnogorsk
# Processing Record 47 of Set 5 | mahebourg
# Processing Record 48 of Set 5 | rafai
# Processing Record 49 of Set 5 | xuddur
# Processing Record 50 of Set 5 | sarh
# Processing Record 1 of Set 6 | ponnampet
# City not found. Skipping...
# Processing Record 2 of Set 6 | akhtubinsk
# Processing Record 3 of Set 6 | ornskoldsvik
# City not found. Skipping...
# Processing Record 4 of Set 6 | gamboma
# Processing Record 5 of Set 6 | ritchie
# Processing Record 6 of Set 6 | bilibino
# Processing Record 7 of Set 6 | bathsheba
# Processing Record 8 of Set 6 | aklavik
# Processing Record 9 of Set 6 | cherskiy
# Processing Record 10 of Set 6 | ossora
# Processing Record 11 of Set 6 | goderich
# City not found. Skipping...
# Processing Record 12 of Set 6 | camacha
# Processing Record 13 of Set 6 | malkangiri
# Processing Record 14 of Set 6 | russell
# Processing Record 15 of Set 6 | derzhavinsk
# Processing Record 16 of Set 6 | natal
# Processing Record 17 of Set 6 | mahajanga
# Processing Record 18 of Set 6 | kulhudhuffushi
# Processing Record 19 of Set 6 | waverley
# Processing Record 20 of Set 6 | kavaratti
# City not found. Skipping...
# Processing Record 21 of Set 6 | kloulklubed
# Processing Record 22 of Set 6 | graham
# Processing Record 23 of Set 6 | ambon
# City not found. Skipping...
# Processing Record 24 of Set 6 | barahona
# Processing Record 25 of Set 6 | nhulunbuy
# Processing Record 26 of Set 6 | kaohsiung
# Processing Record 27 of Set 6 | hailey
# Processing Record 28 of Set 6 | brae
# City not found. Skipping...
# Processing Record 29 of Set 6 | kikwit
# Processing Record 30 of Set 6 | liku
# City not found. Skipping...
# Processing Record 31 of Set 6 | ixtapa
# Processing Record 32 of Set 6 | warrington
# Processing Record 33 of Set 6 | cadillac
# Processing Record 34 of Set 6 | lata
# Processing Record 35 of Set 6 | hasaki
# City not found. Skipping...
# Processing Record 36 of Set 6 | shache
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 37 of Set 6 | visnes
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 38 of Set 6 | chabahar
# Processing Record 39 of Set 6 | tungor
# Processing Record 40 of Set 6 | phuket
# Processing Record 41 of Set 6 | penzance
# Processing Record 42 of Set 6 | seoul
# Processing Record 43 of Set 6 | fasa
# Processing Record 44 of Set 6 | manbij
# Processing Record 45 of Set 6 | necochea
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 46 of Set 6 | champasak
# City not found. Skipping...
# Processing Record 47 of Set 6 | madimba
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 6 | tucuman
# Processing Record 49 of Set 6 | lucapa
# City not found. Skipping...
# Processing Record 50 of Set 6 | noumea
# Processing Record 1 of Set 7 | sur
# Processing Record 2 of Set 7 | kisiwani
# Processing Record 3 of Set 7 | satipo
# Processing Record 4 of Set 7 | sulangan
# Processing Record 5 of Set 7 | rajshahi
# Processing Record 6 of Set 7 | hamilton
# Processing Record 7 of Set 7 | khartoum
# Processing Record 8 of Set 7 | beibei
# Processing Record 9 of Set 7 | bloomington
# Processing Record 10 of Set 7 | ryotsu
# Processing Record 11 of Set 7 | meulaboh
# Processing Record 12 of Set 7 | gazojak
# Processing Record 13 of Set 7 | alexandria
# Processing Record 14 of Set 7 | srbobran
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 15 of Set 7 | gamba
# Processing Record 16 of Set 7 | guasdualito
# City not found. Skipping...
# Processing Record 17 of Set 7 | palauig
# Processing Record 18 of Set 7 | katobu
# Processing Record 19 of Set 7 | tanuma
# City not found. Skipping...
# Processing Record 20 of Set 7 | samarai
# Processing Record 21 of Set 7 | tallahassee
# Processing Record 22 of Set 7 | constitucion
# Processing Record 23 of Set 7 | taltal
# City not found. Skipping...
# Processing Record 24 of Set 7 | hornepayne
# Processing Record 25 of Set 7 | pangnirtung
# Processing Record 26 of Set 7 | tumut
# Processing Record 27 of Set 7 | mbini
# City not found. Skipping...
# Processing Record 28 of Set 7 | aksu
# Processing Record 29 of Set 7 | coihaique
# Processing Record 30 of Set 7 | ulaanbaatar
# Processing Record 31 of Set 7 | poum
# Processing Record 32 of Set 7 | cukai
# Processing Record 33 of Set 7 | nemuro
# Processing Record 34 of Set 7 | kuroiso
# Processing Record 35 of Set 7 | ostrovnoy
# Processing Record 36 of Set 7 | ust-koksa
# Processing Record 37 of Set 7 | bafut
# Processing Record 38 of Set 7 | takoradi
# Processing Record 39 of Set 7 | machilipatnam
# City not found. Skipping...
# Processing Record 40 of Set 7 | kalevala
# Processing Record 41 of Set 7 | manthani
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 7 | siderno
# Processing Record 43 of Set 7 | garowe
# Processing Record 44 of Set 7 | gabrovo
# City not found. Skipping...
# Processing Record 45 of Set 7 | xuanhua
# City not found. Skipping...
# Processing Record 46 of Set 7 | banjarmasin
# City not found. Skipping...
# Processing Record 47 of Set 7 | bolobo
# City not found. Skipping...
# Processing Record 48 of Set 7 | benghazi
# Processing Record 49 of Set 7 | zheshart
# Processing Record 50 of Set 7 | kollegal
# Processing Record 1 of Set 8 | ucluelet
# Processing Record 2 of Set 8 | motril
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 8 | kysyl-syr
# Processing Record 4 of Set 8 | mizdah
# Processing Record 5 of Set 8 | paamiut
# City not found. Skipping...
# Processing Record 6 of Set 8 | waipawa
# City not found. Skipping...
# Processing Record 7 of Set 8 | bonavista
# Processing Record 8 of Set 8 | bambanglipuro
# Processing Record 9 of Set 8 | canico
# Processing Record 10 of Set 8 | yumen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 11 of Set 8 | inhambane
# City not found. Skipping...
# Processing Record 12 of Set 8 | menongue
# City not found. Skipping...
# Processing Record 13 of Set 8 | edinburgh
# City not found. Skipping...
# Processing Record 14 of Set 8 | labuhan
# Processing Record 15 of Set 8 | toila
# Processing Record 16 of Set 8 | kouroussa
# Processing Record 17 of Set 8 | salalah
# Processing Record 18 of Set 8 | fallon
# Processing Record 19 of Set 8 | harper
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 20 of Set 8 | teya
# Processing Record 21 of Set 8 | riverton
# Processing Record 22 of Set 8 | bubaque
# Processing Record 23 of Set 8 | ekhabi
# City not found. Skipping...
# Processing Record 24 of Set 8 | nome
# Processing Record 25 of Set 8 | goundi
# Processing Record 26 of Set 8 | yingcheng
# City not found. Skipping...
# Processing Record 27 of Set 8 | manosque
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 8 | saint-pierre
# Processing Record 29 of Set 8 | cayenne
# Processing Record 30 of Set 8 | qinzhou
# Processing Record 31 of Set 8 | kaeo
# Processing Record 32 of Set 8 | calama
# City not found. Skipping...
# Processing Record 33 of Set 8 | gari
# City not found. Skipping...
# Processing Record 34 of Set 8 | kalmunai
# Processing Record 35 of Set 8 | mapimi
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 36 of Set 8 | oyon
# Processing Record 37 of Set 8 | methoni
# Processing Record 38 of Set 8 | kralendijk
# Processing Record 39 of Set 8 | socorro
# Processing Record 40 of Set 8 | taoudenni
# Processing Record 41 of Set 8 | izumo
# Processing Record 42 of Set 8 | maningrida
# Processing Record 43 of Set 8 | bakchar
# Processing Record 44 of Set 8 | charlottesville
# Processing Record 45 of Set 8 | tiznit
# Processing Record 46 of Set 8 | shenjiamen
# Processing Record 47 of Set 8 | okhotsk
# Processing Record 48 of Set 8 | vao
# Processing Record 49 of Set 8 | hermon
# Processing Record 50 of Set 8 | coracora
# Processing Record 1 of Set 9 | napasar
# Processing Record 2 of Set 9 | nirasaki
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 9 | camacupa
# City not found. Skipping...
# Processing Record 4 of Set 9 | champerico
# Processing Record 5 of Set 9 | hinche
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 6 of Set 9 | ferndale
# City not found. Skipping...
# Processing Record 7 of Set 9 | oneonta
# Processing Record 8 of Set 9 | shinpokh
# Processing Record 9 of Set 9 | mayumba
# City not found. Skipping...
# Processing Record 10 of Set 9 | rennes
# Processing Record 11 of Set 9 | dologon
# Processing Record 12 of Set 9 | axim
# Processing Record 13 of Set 9 | sosnovo-ozerskoye
# City not found. Skipping...
# Processing Record 14 of Set 9 | upington
# Processing Record 15 of Set 9 | ghindaresti
# Processing Record 16 of Set 9 | rundu
# City not found. Skipping...
# Processing Record 17 of Set 9 | springdale
# Processing Record 18 of Set 9 | kohlu
# Processing Record 19 of Set 9 | ukiah
# Processing Record 20 of Set 9 | villeneuve-sur-lot
# Processing Record 21 of Set 9 | xai-xai
# Processing Record 22 of Set 9 | kampot
# City not found. Skipping...
# Processing Record 23 of Set 9 | staszow
# City not found. Skipping...
# Processing Record 24 of Set 9 | callaway
# Processing Record 25 of Set 9 | shanghai
# Processing Record 26 of Set 9 | xiongzhou
# Processing Record 27 of Set 9 | mweka
# Processing Record 28 of Set 9 | mnogovershinnyy
# Processing Record 29 of Set 9 | kholm
# Processing Record 30 of Set 9 | baiao
# Processing Record 31 of Set 9 | jiangyou
# Processing Record 32 of Set 9 | havre-saint-pierre
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 33 of Set 9 | khash
# Processing Record 34 of Set 9 | alcaniz
# Processing Record 35 of Set 9 | talcahuano
# Processing Record 36 of Set 9 | buala
# Processing Record 37 of Set 9 | strelka
# Processing Record 38 of Set 9 | kolaras
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 39 of Set 9 | srednekolymsk
# Processing Record 40 of Set 9 | kununurra
# City not found. Skipping...
# Processing Record 41 of Set 9 | pangai
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 42 of Set 9 | kieta
# Processing Record 43 of Set 9 | campoverde
# Processing Record 44 of Set 9 | dwarka
# Processing Record 45 of Set 9 | southbridge
# Processing Record 46 of Set 9 | deputatskiy
# Processing Record 47 of Set 9 | broome
# Processing Record 48 of Set 9 | leninskiy
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 49 of Set 9 | nouadhibou
# Processing Record 50 of Set 9 | oranjemund
# City not found. Skipping...
# Processing Record 1 of Set 10 | sokoni
# City not found. Skipping...
# Processing Record 2 of Set 10 | zaysan
# Processing Record 3 of Set 10 | dingle
# City not found. Skipping...
# Processing Record 4 of Set 10 | nouakchott
# Processing Record 5 of Set 10 | lodja
# City not found. Skipping...
# Processing Record 6 of Set 10 | zarinsk
# Processing Record 7 of Set 10 | vierzon
# City not found. Skipping...
# Processing Record 8 of Set 10 | bealanana
# Processing Record 9 of Set 10 | dauphin
# Processing Record 10 of Set 10 | chegutu
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Set the dictionary for the DataFrame

weather_datadict = {
            "City": out_cities,
            "Cloudiness": cloudiness,
            "Country": country,
            "Date": date,
            "Humidity": humidity ,
            "Lat": latitude ,
            "Lng": longitude ,
            "Max Temp": max_temp ,
            "Wind Speed": wind_speed  
            
            }

# %%
# Convert to DataFrame and display the DataFrame as per the requirement
df_weather = pd.DataFrame(weather_datadict)
df_weather.head()
# Out:
#          City  Cloudiness Country        Date  Humidity     Lat     Lng  \
# 0      huaraz          31      PE  1578376800        94   -9.53  -77.53
# 1      albany          96      US  1578376800        79   42.65  -73.75
# 2  georgetown          63      GY  1578376800        76    6.80  -58.16
# 3  bredasdorp         100      ZA  1578376800        77  -34.53   20.04
# 4   esperance           0      AU  1578376800        47  -33.86  121.89
#
#   Max Temp  Wind Speed
# 0    37.13        0.49
# 1    31.69        9.44
# 2    79.07       13.82
# 3    71.46       12.15
# 4    98.80       17.96

# %%
# Set the dictionary for the DataFrame with date format YYYY-MM-DD

weather_dict_new_dict= {
            "City": out_cities,
            "Cloudiness": cloudiness,
            "Country": country,
            "Date(YYYY-MM-DD)": date_yyyymmdd,
            "Humidity": humidity ,
            "Lat": latitude ,
            "Lng": longitude ,
            "Max Temp": max_temp ,
            "Wind Speed": wind_speed  
            
            }

# %%
# Convert to the DataFrame 
newweather_df = pd.DataFrame(weather_dict_new_dict)

# %%
# format the date column
newweather_df["Date(YYYY-MM-DD)"] = newweather_df["Date(YYYY-MM-DD)"].str[:11]

# %%
# Display the new DataFrame 
newweather_df.head()
# Out:
#          City  Cloudiness Country Date(YYYY-MM-DD)  Humidity     Lat     Lng  \
# 0      huaraz          31      PE      2020-01-07         94   -9.53  -77.53
# 1      albany          96      US      2020-01-07         79   42.65  -73.75
# 2  georgetown          63      GY      2020-01-07         76    6.80  -58.16
# 3  bredasdorp         100      ZA      2020-01-07         77  -34.53   20.04
# 4   esperance           0      AU      2020-01-07         47  -33.86  121.89
#
#   Max Temp  Wind Speed
# 0    37.13        0.49
# 1    31.69        9.44
# 2    79.07       13.82
# 3    71.46       12.15
# 4    98.80       17.96

# %%
# Save the output to a csv file "weather_data.csv"
df_weather.to_csv('Output_Data/weather_data.csv')

# %%
df_weather.to_csv('Output_Data/weather_data_updated_date.csv')

# %%
# Display the count of all the variables
df_weather.count()
# Out:
# City          460
# Cloudiness    460
# Country       460
# Date          460
# Humidity      460
# Lat           460
# Lng           460
# Max Temp      460
# Wind Speed    460
# dtype: int64

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from datetime import date
today_date = date.today().strftime('%m/%d/%Y') 
today_date
# Out:
# '01/06/2020'

# %%
plt.scatter(df_weather["Lat"], df_weather["Max Temp"], edgecolors = "black", facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature ("+ today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Max temp (F)")
#plt.xlim(-80,100)
#plt.ylim(min(df_weather["Max Temp"])-20 ,max(df_weather["Max Temp"])+20)
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

#plt.savefig("LatitudeVsTemperaturePlot.png")
plt.savefig("Output_Plots/LatitudeVsTemperaturePlot.pnge.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Humidity"], edgecolors = "black", facecolors="skyblue", s=20)
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title(" City Latitude vs. Humidity (" + today_date + ")" ) 
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsHumidityPlot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Cloudiness"], edgecolors = "black", facecolors="skyblue")
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title("City Latitude vs. Cloudiness (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsCloudinessPlot.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df_weather["Lat"], df_weather["Wind Speed"], edgecolors = "black", facecolors="skyblue")
#plt.xlim(-60, 80)
#plt.ylim(0, 100)
plt.title("City Latitude vs. Wind Speed (" + today_date + ")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.grid(b = True, which = "major", axis = "both", linestyle = "-", color= "lightgrey")

plt.savefig("Output_Plots/LatitudeVsWindSpeedPlot.png")
plt.show()
